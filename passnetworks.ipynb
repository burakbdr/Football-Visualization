# %% [markdown]
# ## Imports

# %%
import pandas as pd
from mplsoccer.pitch import Pitch

# %% [markdown]
# ## Get Data

# %%
df = pd.read_csv('/Users/burakbedir/Desktop/B/Projects/Football-Visualization/datasets/valladolidA.csv')

df
# Out:
#               id  eventId  minute  second      teamId     x     y  period  \
# 0     2248226915        2       0     0.0   Barcelona   0.0   0.0       1
# 1     2248226919        2       0     0.0  Valladolid   0.0   0.0       1
# 2     2248226929        3       0     1.0   Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0   Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0   Barcelona  36.6  56.6       1
# ...          ...      ...     ...     ...         ...   ...   ...     ...
# 1673  2248257153     1030      94     0.0   Barcelona   0.0   0.0       2
# 1674  2248257159      779       0     0.0  Valladolid   0.0   0.0      14
# 1675  2248257147     1031       0     0.0   Barcelona   0.0   0.0      14
# 1676  2248274127        1       0     0.0  Valladolid   0.0   0.0      16
# 1677  2248257151        1       0     0.0   Barcelona   0.0   0.0      16
#
#               type     outcome  playerId  endX  endY
# ...

# %%
# Filter df to get only Barcelona
df = df[df['teamId']== 'Barcelona']

# %%
df
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 0     2248226915        2       0     0.0  Barcelona   0.0   0.0       1
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1668  2248257083     1028      93    55.0  Barcelona  77.1  49.0       2
# 1671  2248257093     1029      93    57.0  Barcelona  86.9  49.6       2
# 1673  2248257153     1030      94     0.0  Barcelona   0.0   0.0       2
# 1675  2248257147     1031       0     0.0  Barcelona   0.0   0.0      14
# 1677  2248257151        1       0     0.0  Barcelona   0.0   0.0      16
#
#                type     outcome  playerId  endX  endY
# ...

# %%
# Create passer and reciever columns
df['passer'] = df['playerId']
df['recipient'] = df['playerId'].shift(-1)

# Filter df only for passes 
passes = df[df['type']=='Pass']
succesfull = passes[passes['outcome']=='Successful']
# Out:
# /var/folders/0v/n3w11jxs0zxdx0ty34xv_fx40000gn/T/ipykernel_5653/1126733784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['passer'] = df['playerId']
# /var/folders/0v/n3w11jxs0zxdx0ty34xv_fx40000gn/T/ipykernel_5653/1126733784.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['recipient'] = df['playerId'].shift(-1)

# %%
succesfull
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# 6     2248226975        7       0     8.0  Barcelona  11.2  53.7       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1651  2248256867     1018      93    14.0  Barcelona  76.7  31.8       2
# 1652  2248256869     1019      93    17.0  Barcelona  79.6  24.2       2
# 1653  2248256983     1020      93    18.0  Barcelona  77.1  56.4       2
# 1654  2248256989     1021      93    20.0  Barcelona  68.3  55.2       2
# 1667  2248257081     1027      93    50.0  Barcelona  75.6   4.6       2
#
#       type     outcome  playerId  endX  endY   passer  recipient
# ...

# %%
subs = df[df['type'] == 'SubstitutionOff']
subs = subs['minute']
firstSub = subs.min()

# %%
firstSub
# Out:
# np.int64(70)

# %%
succesfull = succesfull[succesfull['minute'] < firstSub]

# %%
succesfull
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# 6     2248226975        7       0     8.0  Barcelona  11.2  53.7       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1230  2248252877      782      69    30.0  Barcelona  83.1  42.8       2
# 1231  2248252881      783      69    32.0  Barcelona  90.5  23.0       2
# 1234  2248252897      785      69    36.0  Barcelona  84.6  27.7       2
# 1235  2248252905      786      69    37.0  Barcelona  90.7  14.3       2
# 1236  2248252913      787      69    38.0  Barcelona  88.4  15.3       2
#
#       type     outcome  playerId  endX  endY  passer  recipient
# ...

# %%
# Change dtype of pass and recvr
passr= pd.to_numeric(succesfull['passer'], downcast='integer')
rec= pd.to_numeric(succesfull['recipient'], downcast='integer')

succesfull['passer'] = passr
succesfull['recipient'] = rec
# Out:
# /var/folders/0v/n3w11jxs0zxdx0ty34xv_fx40000gn/T/ipykernel_5653/4492374.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   succesfull['passer'] = passr
# /var/folders/0v/n3w11jxs0zxdx0ty34xv_fx40000gn/T/ipykernel_5653/4492374.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   succesfull['recipient'] = rec

# %%
succesfull
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# 6     2248226975        7       0     8.0  Barcelona  11.2  53.7       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1230  2248252877      782      69    30.0  Barcelona  83.1  42.8       2
# 1231  2248252881      783      69    32.0  Barcelona  90.5  23.0       2
# 1234  2248252897      785      69    36.0  Barcelona  84.6  27.7       2
# 1235  2248252905      786      69    37.0  Barcelona  90.7  14.3       2
# 1236  2248252913      787      69    38.0  Barcelona  88.4  15.3       2
#
#       type     outcome  playerId  endX  endY  passer  recipient
# ...

# %%
# Create average locations
average_locations = succesfull.groupby('passer').agg({'x':['mean'], 'y':['mean','count']}) 
average_locations.columns = ['x','y','count']

# %%
average_locations
# Out:
#                 x          y  count
# passer
# 1        7.124000  50.324000     25
# 2       68.274359  11.915385     39
# 4       32.895833  43.518750     48
# 8       53.332927  41.608537     82
# 9       69.916667  51.383333      6
# 10      63.201613  42.351613     62
# 15      38.409091  74.378182     55
# 16      69.594286  69.471429     35
# 18      55.242553  83.793617     47
# 21      55.663636  52.263636     55
# 28      49.156863  16.282353     51

# %%
pass_between = succesfull.groupby(['passer','recipient']).id.count().reset_index()
pass_between.rename({'id':'pass_count'}, axis='columns',inplace=True)

#merge to get all new df
pass_between = pass_between.merge(average_locations, left_on='passer', right_index=True)
pass_between = pass_between.merge(average_locations, left_on='recipient', right_index=True,suffixes=['','_end'])

# %%
pass_between
# Out:
#     passer  recipient  pass_count          x          y  count      x_end  \
# 0        1          2           3   7.124000  50.324000     25  68.274359
# 1        1          4           3   7.124000  50.324000     25  32.895833
# 2        1          8           4   7.124000  50.324000     25  53.332927
# 3        1          9           1   7.124000  50.324000     25  69.916667
# 4        1         15           4   7.124000  50.324000     25  38.409091
# ..     ...        ...         ...        ...        ...    ...        ...
# 85      28          8          13  49.156863  16.282353     51  53.332927
# 86      28          9           3  49.156863  16.282353     51  69.916667
# 87      28         10           5  49.156863  16.282353     51  63.201613
# 88      28         18           1  49.156863  16.282353     51  55.242553
# 89      28         21           5  49.156863  16.282353     51  55.663636
#
#         y_end  count_end
# 0   11.915385         39
# 1   43.518750         48
# ...

# %%
# High passing team like Barcelona we can filter 
pass_between = pass_between[pass_between['pass_count']>3]

# %%
pass_between
# Out:
#     passer  recipient  pass_count          x          y  count      x_end  \
# 2        1          8           4   7.124000  50.324000     25  53.332927
# 4        1         15           4   7.124000  50.324000     25  38.409091
# 11       2          8          11  68.274359  11.915385     39  53.332927
# 13       2         10          11  68.274359  11.915385     39  63.201613
# 15       2         21           5  68.274359  11.915385     39  55.663636
# 16       2         28           7  68.274359  11.915385     39  49.156863
# 17       4          1           5  32.895833  43.518750     48   7.124000
# 19       4          8           6  32.895833  43.518750     48  53.332927
# 21       4         15          20  32.895833  43.518750     48  38.409091
# 23       4         21           6  32.895833  43.518750     48  55.663636
# 24       4         28           7  32.895833  43.518750     48  49.156863
# 26       8          2           8  53.332927  41.608537     82  68.274359
# ...

# %%
# Plot the pitch

pitch = Pitch(pitch_type='uefa', pitch_color='#0583F2', line_color='#FFFCF7')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#FFFCF7')


# Plot the arrows

arrows = pitch.arrows(1.2*pass_between.x,.8*pass_between.y,1.2*pass_between.x_end,.8*pass_between.y_end,
                     width = 5, headwidth = 5, color = '#D90479', ax = ax, zorder = 1, alpha = .5)

# Plot the nodes

nodes = pitch.scatter(1.2*average_locations.x,.8*average_locations.y,
                     s = 300, color = '#FFFCF7', edgecolors = 'black', linewidth = 2.5, alpha = 1, zorder = 1, ax=ax)
